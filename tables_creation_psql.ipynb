# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
import datetime as dt

from finvizfinance.quote import finvizfinance

# %%
dat = yf.Ticker("MSFT")

# %%
dat
# Out:
# yfinance.Ticker object <MSFT>

# %%
stock = finvizfinance('MSFT')

# %%
news_df = stock.ticker_news()
news_df
# Out:
#                   Date                                              Title  \
# 0  2025-02-26 13:52:00  Magnificent Seven Stocks: Nvidia Rallies Ahead...
# 1  2025-02-26 13:47:00  Nvidias Shaken Aura of Invincibility Is Set fo...
# 2  2025-02-26 13:08:00  Microsoft Invests in Veeam to Advance AI-Power...
# 3  2025-02-26 12:44:00   Amazon to Launch Generative-AI Alexa+ Next Month
# 4  2025-02-26 12:34:00  Salesforce, Microsoft executives spar over AI ...
# ..                 ...                                                ...
# 95 2025-02-24 04:00:00  Nvidia to report Q4 earnings Wednesday as tari...
# 96 2025-02-24 03:34:00  Prediction: 2 AI Stocks Will Be Worth More Tha...
# 97 2025-02-23 22:00:00  Spark New Zealand Ltd (NZTCF) (HY 2025) Earnin...
# 98 2025-02-23 12:22:00  At a 6-Month Low, Here's My Top Dow Jones Stoc...
# 99 2025-02-23 09:55:00  Silicon Valley is going all in on humanoid rob...
#
#                                                  Link  \
# ...

# %%
CREATE TABLE news_data (
    id SERIAL PRIMARY KEY,
    ticker VARCHAR(10) NOT NULL,
    date TIMESTAMP NOT NULL,
    headline TEXT NOT NULL,
    link TEXT NOT NULL,
    source VARCHAR(100) NOT NULL,
    CONSTRAINT unique_ticker_date_headline UNIQUE (ticker, date, headline)
);

# %%
print(dat.info)
print(dat.calendar)
# Out:
# {'address1': 'One Microsoft Way', 'city': 'Redmond', 'state': 'WA', 'zip': '98052-6399', 'country': 'United States', 'phone': '425 882 8080', 'website': 'https://www.microsoft.com', 'industry': 'Software - Infrastructure', 'industryKey': 'software-infrastructure', 'industryDisp': 'Software - Infrastructure', 'sector': 'Technology', 'sectorKey': 'technology', 'sectorDisp': 'Technology', 'longBusinessSummary': 'Microsoft Corporation develops and supports software, services, devices and solutions worldwide. The Productivity and Business Processes segment offers office, exchange, SharePoint, Microsoft Teams, office 365 Security and Compliance, Microsoft viva, and Microsoft 365 copilot; and office consumer services, such as Microsoft 365 consumer subscriptions, Office licensed on-premises, and other office services. This segment also provides LinkedIn; and dynamics business solutions, including Dynamics 365, a set of intelligent, cloud-based applications across ERP, CRM, power apps, and p
# ...

# %%
###SQL TABLES from company_info

CREATE TABLE company_info (
    id SERIAL PRIMARY KEY,
    ticker VARCHAR(10) NOT NULL UNIQUE,
    name VARCHAR(100) NOT NULL,
    sector VARCHAR(50),
    industry VARCHAR(50),
    
    market_cap BIGINT,
    enterprise_value BIGINT,
    total_revenue BIGINT,
    ebitda BIGINT,
    net_income BIGINT,
    total_debt BIGINT,
    free_cashflow BIGINT,
    return_on_assets FLOAT,
    return_on_equity FLOAT,

    trailing_pe FLOAT,
    forward_pe FLOAT,
    price_to_sales FLOAT,
    price_to_book FLOAT,

    dividend_rate FLOAT,
    dividend_yield FLOAT,
    payout_ratio FLOAT,

    shares_outstanding BIGINT,
    held_percent_institutions FLOAT,
    held_percent_insiders FLOAT,
    beta FLOAT,
    fifty_two_week_high FLOAT,
    fifty_two_week_low FLOAT,

    earnings_growth FLOAT,
    revenue_growth FLOAT,
    profit_margins FLOAT,
    gross_margins FLOAT,
    operating_margins FLOAT,
    ebitda_margins FLOAT,

    target_high_price FLOAT,
    target_low_price FLOAT,
    target_mean_price FLOAT,
    recommendation_mean FLOAT,
    recommendation_key VARCHAR(20),
    number_of_analyst_opinions INT
);

# %%
print(dat.quarterly_income_stmt)
# Out:
#                                                        2024-12-31  \
# Tax Effect Of Unusual Items                          -203220000.0
# Tax Rate For Calcs                                           0.18
# Normalized EBITDA                                   37915000000.0
# Total Unusual Items                                 -1129000000.0
# Total Unusual Items Excluding Goodwill              -1129000000.0
# Net Income From Continuing Operation Net Minori...  24108000000.0
# Reconciled Depreciation                              6827000000.0
# Reconciled Cost Of Revenue                          21799000000.0
# EBITDA                                              36786000000.0
# EBIT                                                29959000000.0
# Net Interest Income                                     6000000.0
# Interest Expense                                      594000000.0
# Interest Income                                       600000000.0
# ...

# %%
dat.quarterly_financials.index
# Out:
# Index(['Tax Effect Of Unusual Items', 'Tax Rate For Calcs',
#        'Normalized EBITDA', 'Total Unusual Items',
#        'Total Unusual Items Excluding Goodwill',
#        'Net Income From Continuing Operation Net Minority Interest',
#        'Reconciled Depreciation', 'Reconciled Cost Of Revenue', 'EBITDA',
#        'EBIT', 'Net Interest Income', 'Interest Expense', 'Interest Income',
#        'Normalized Income',
#        'Net Income From Continuing And Discontinued Operation',
#        'Total Expenses', 'Total Operating Income As Reported',
#        'Diluted Average Shares', 'Basic Average Shares', 'Diluted EPS',
#        'Basic EPS', 'Diluted NI Availto Com Stockholders',
#        'Net Income Common Stockholders', 'Net Income',
#        'Net Income Including Noncontrolling Interests',
#        'Net Income Continuous Operations', 'Tax Provision', 'Pretax Income',
#        'Other Income Expense', 'Other Non Operating Income Expenses',
# ...

# %%
dat.quarterly_financials
# Out:
#                                                        2024-12-31  \
# Tax Effect Of Unusual Items                          -203220000.0
# Tax Rate For Calcs                                           0.18
# Normalized EBITDA                                   37915000000.0
# Total Unusual Items                                 -1129000000.0
# Total Unusual Items Excluding Goodwill              -1129000000.0
# Net Income From Continuing Operation Net Minori...  24108000000.0
# Reconciled Depreciation                              6827000000.0
# Reconciled Cost Of Revenue                          21799000000.0
# EBITDA                                              36786000000.0
# EBIT                                                29959000000.0
# Net Interest Income                                     6000000.0
# Interest Expense                                      594000000.0
# Interest Income                                       600000000.0
# ...

# %%
## SQL TABLES QUARTERLY BALANCE
CREATE TABLE quarterly_financials (
    id SERIAL PRIMARY KEY,
    ticker VARCHAR(10) NOT NULL,  
    date_reported DATE NOT NULL, 
    tax_effect_of_unusual_items FLOAT,
    tax_rate_for_calcs FLOAT,
    normalized_ebitda FLOAT,
    total_unusual_items FLOAT,
    total_unusual_items_excl_goodwill FLOAT,
    net_income_cont_operation FLOAT,
    reconciled_depreciation FLOAT,
    reconciled_cost_of_revenue FLOAT,
    ebitda FLOAT,
    ebit FLOAT,
    net_interest_income FLOAT,
    interest_expense FLOAT,
    interest_income FLOAT,
    normalized_income FLOAT,
    net_income_cont_discont_operation FLOAT,
    total_expenses FLOAT,
    total_operating_income FLOAT,
    diluted_avg_shares FLOAT,
    basic_avg_shares FLOAT,
    diluted_eps FLOAT,
    basic_eps FLOAT,
    diluted_ni_availto_com_stockholders FLOAT,
    net_income_common_stockholders FLOAT,
    net_income FLOAT,
    net_income_incl_noncontrolling_interests FLOAT,
    net_income_continuous_operations FLOAT,
    tax_provision FLOAT,
    pretax_income FLOAT,
    other_income_expense FLOAT,
    other_non_operating_income_expenses FLOAT,
    special_income_charges FLOAT,
    write_off FLOAT,
    gain_on_sale_of_security FLOAT,
    net_non_operating_interest_income_expense FLOAT,
    interest_expense_non_operating FLOAT,
    interest_income_non_operating FLOAT,
    operating_income FLOAT,
    operating_expense FLOAT,
    research_and_development FLOAT,
    selling_general_and_admin FLOAT,
    selling_and_marketing_expense FLOAT,
    general_and_admin_expense FLOAT,
    other_gand_a FLOAT,
    gross_profit FLOAT,
    cost_of_revenue FLOAT,
    total_revenue FLOAT,
    operating_revenue FLOAT,
    CONSTRAINT unique_ticker_date UNIQUE (ticker, date_reported)
);

# %%
print(dat.history(period='1mo'))
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2025-01-27 00:00:00-05:00  423.161523  434.329133  422.652534  433.690399
# 2025-01-28 00:00:00-05:00  433.730323  447.482746  430.516765  446.305115
# 2025-01-29 00:00:00-05:00  445.796115  445.985737  439.518694  441.444824
# 2025-01-30 00:00:00-05:00  417.931980  422.013792  412.333221  414.159546
# 2025-01-31 00:00:00-05:00  418.141600  419.848170  414.079737  414.229431
# 2025-02-03 00:00:00-05:00  410.776349  414.578723  407.842230  410.097717
# 2025-02-04 00:00:00-05:00  411.864167  413.091716  408.920058  411.544800
# 2025-02-05 00:00:00-05:00  411.524861  413.001880  409.578751  412.462982
# 2025-02-06 00:00:00-05:00  413.171550  417.363157  413.171550  414.987915
# 2025-02-07 00:00:00-05:00  415.646597  417.812238  407.283362  408.930054
# 2025-02-10 00:00:00-05:00  412.882120  414.628618  410.097725  411.395111
# 2025-02-11 00:00:00-05:00  408.820283  411.664555  408.480936  410.616669
# ...

# %%
CREATE TABLE historical_prices ( 
    id SERIAL PRIMARY KEY,
    ticker VARCHAR(10) NOT NULL,
    date TIMESTAMP NOT NULL,
    open_price DECIMAL(10,2) NOT NULL,
    high_price DECIMAL(10,2) NOT NULL, 
    low_price DECIMAL(10,2) NOT NULL, 
    close_price DECIMAL(10,2) NOT NULL,
    adj_close_price DECIMAL(10,2) NOT NULL,
    volume BIGINT NOT NULL
);"

# %%
print(dat.option_chain(dat.options[0]).calls)
# Out:
#          contractSymbol             lastTradeDate  strike  lastPrice     bid  \
# 0   MSFT250228C00240000 2025-02-12 15:08:15+00:00   240.0     167.72  160.95
# 1   MSFT250228C00250000 2025-02-21 20:17:26+00:00   250.0     159.59  150.95
# 2   MSFT250228C00260000 2025-02-19 16:17:02+00:00   260.0     151.12  140.95
# 3   MSFT250228C00270000 2025-02-06 16:30:58+00:00   270.0     147.30  131.20
# 4   MSFT250228C00300000 2025-01-31 19:55:07+00:00   300.0     117.17  101.20
# ..                  ...                       ...     ...        ...     ...
# 64  MSFT250228C00525000 2025-01-30 17:45:47+00:00   525.0       0.07    0.00
# 65  MSFT250228C00530000 2025-02-14 15:25:23+00:00   530.0       0.01    0.00
# 66  MSFT250228C00540000 2025-02-07 19:32:08+00:00   540.0       0.02    0.00
# 67  MSFT250228C00550000 2025-02-07 18:58:41+00:00   550.0       0.01    0.00
# 68  MSFT250228C00560000 2025-02-25 17:40:42+00:00   560.0       0.01    0.00
#
# ...

# %%
# SQL TABLES options

CREATE TABLE options_data (
    id SERIAL PRIMARY KEY,
    contract_symbol VARCHAR(50) NOT NULL,  -
    ticker VARCHAR(10) NOT NULL,  
    last_trade_date TIMESTAMP NOT NULL,  
    strike FLOAT NOT NULL,  
    last_price FLOAT NOT NULL,  
    bid FLOAT,  
    ask FLOAT,  
    change FLOAT,  -- Cambio en el precio
    percent_change FLOAT,  
    volume INT,  
    open_interest INT,  -- Número de contratos abiertos
    implied_volatility FLOAT,  -- Volatilidad implícita
    in_the_money BOOLEAN NOT NULL,  
    contract_size VARCHAR(10) NOT NULL,  
    currency VARCHAR(3) NOT NULL,  
    CONSTRAINT unique_contract UNIQUE (contract_symbol)
);

# %%
dat.option_chain(dat.options[0]).calls.columns
# Out:
# Index(['contractSymbol', 'lastTradeDate', 'strike', 'lastPrice', 'bid', 'ask',
#        'change', 'percentChange', 'volume', 'openInterest',
#        'impliedVolatility', 'inTheMoney', 'contractSize', 'currency'],
#       dtype='object')

# %%
dat.balance_sheet
# Out:
#                                                       2024-06-30  \
# Ordinary Shares Number                              7434138859.0
# Share Issued                                        7434138859.0
# Net Debt                                           33315000000.0
# Total Debt                                         67127000000.0
# Tangible Book Value                               121660000000.0
# ...                                                          ...
# Cash Cash Equivalents And Short Term Investments   75531000000.0
# Other Short Term Investments                       57216000000.0
# Cash And Cash Equivalents                          18315000000.0
# Cash Equivalents                                    6744000000.0
# Cash Financial                                     11571000000.0
#
#                                                       2023-06-30  \
# Ordinary Shares Number                              7432000000.0
# ...

# %%
dat.balance_sheet.index
# Out:
# Index(['Ordinary Shares Number', 'Share Issued', 'Net Debt', 'Total Debt',
#        'Tangible Book Value', 'Invested Capital', 'Working Capital',
#        'Net Tangible Assets', 'Capital Lease Obligations',
#        'Common Stock Equity', 'Total Capitalization',
#        'Total Equity Gross Minority Interest', 'Stockholders Equity',
#        'Gains Losses Not Affecting Retained Earnings',
#        'Other Equity Adjustments', 'Retained Earnings', 'Capital Stock',
#        'Common Stock', 'Total Liabilities Net Minority Interest',
#        'Total Non Current Liabilities Net Minority Interest',
#        'Other Non Current Liabilities', 'Tradeand Other Payables Non Current',
#        'Non Current Deferred Liabilities', 'Non Current Deferred Revenue',
#        'Non Current Deferred Taxes Liabilities',
#        'Long Term Debt And Capital Lease Obligation',
#        'Long Term Capital Lease Obligation', 'Long Term Debt',
#        'Current Liabilities', 'Other Current Liabilities',
# ...

# %% [markdown]
# # Recomendaciones

# %%
print(dat.analyst_price_targets)
# Out:
# {'current': 401.28, 'high': 650.0, 'low': 420.0, 'mean': 508.051, 'median': 500.0}

# %%
dat.recommendations
# Out:
#   period  strongBuy  buy  hold  sell  strongSell
# 0     0m         13   39     5     0           0
# 1    -1m         13   40     5     0           0
# 2    -2m         14   38     5     0           0
# 3    -3m         14   38     5     0           0

# %%
##SQL TABLES

CREATE TABLE Analyst_Recommendations (
    id serial primary key,
    ticker VARCHAR(10) NOT NULL,
    date DATE NOT NULL,
    latest_stock_price FLOAT NOT NULL,
    high_target FLOAT NOT NULL,
    low_target FLOAT NOT NULL,
    mean_target FLOAT NOT NULL,
    median_target FLOAT NOT NULL,
    CONSTRAINT unique_ticker_date_target UNIQUE (ticker, date)
)

CREATE TABLE Analyst_Recommendations_Period(
    id SERIAL PRIMARY KEY,
    ticker VARCHAR(10) NOT NULL,
    date DATE NOT NULL,
    strong_buy INT NOT NULL,
    buy INT NOT NULL,
    hold INT NOT NULL,
    sell INT NOT NULL,
    strong_sell INT NOT NULL,
    CONSTRAINT unique_ticker_date_recommendations UNIQUE (ticker, date),
    CONSTRAINT fk_analyst_recommendations FOREIGN KEY (ticker, date)
        REFERENCES Analyst_Recommendations (ticker, date) ON DELETE CASCADE
)

# %% [markdown]
# # Institutional shareholders

# %%
dat.institutional_holders
# Out:
#   Date Reported                             Holder  pctHeld     Shares  \
# 0    2024-12-31                 Vanguard Group Inc   0.0920  684071705
# 1    2024-12-31                     Blackrock Inc.   0.0775  576226642
# 2    2024-12-31           State Street Corporation   0.0397  295109622
# 3    2024-12-31                           FMR, LLC   0.0266  197512226
# 4    2024-12-31      Geode Capital Management, LLC   0.0226  168128024
# 5    2024-12-31          JP Morgan Chase & Company   0.0182  134943661
# 6    2024-12-31      Price (T.Rowe) Associates Inc   0.0182  135151848
# 7    2024-12-31                     Morgan Stanley   0.0169  125501255
# 8    2024-12-31  Norges Bank Investment Management   0.0142  105202984
# 9    2024-12-31         Northern Trust Corporation   0.0113   83787746
#
#           Value  pctChange
# 0  274045955719     0.0155
# 1  230842146610     0.0263
# 2  118223861346     0.0194
# 3   79125369964    -0.0667
# 4   67353765231     0.0188
# ...

# %%
##SQL TABLES

CREATE TABLE institutional_shareholders (
    id serial primary key,
    ticker VARCHAR(10) NOT NULL,
    date_reported DATE NOT NULL,
    holder VARCHAR(40) NOT NULL,
    pct_held FLOAT NOT NULL,
    shares BIGINT NOT NULL,
    value BIGINT NOT NULL,
    pct_change FLOAT NOT NULL,
    CONSTRAINT unique_institutional_holding UNIQUE (ticker, holder, date_reported)
);

# %% [markdown]
# Fondos

# %%
import yfinance as yf

# %%
spy = yf.Ticker('SPY').funds_data
spy.description
# Out:
# 'The trust seeks to achieve its investment objective by holding a portfolio of the common stocks that are included in the index, with the weight of each stock in the portfolio substantially corresponding to the weight of such stock in the index.'

# %%
spy.top_holdings
# Out:
#                                   Name  Holding Percent
# Symbol
# AAPL                         Apple Inc         0.069699
# MSFT                    Microsoft Corp         0.060293
# NVDA                       NVIDIA Corp         0.057546
# AMZN                    Amazon.com Inc         0.043459
# META        Meta Platforms Inc Class A         0.029354
# GOOGL             Alphabet Inc Class A         0.023291
# TSLA                         Tesla Inc         0.022077
# AVGO                      Broadcom Inc         0.020192
# GOOG              Alphabet Inc Class C         0.019118
# BRK-B   Berkshire Hathaway Inc Class B         0.016784

# %%
##SQL TABLES FUNDS

CREATE TABLE funds_holdings (
    id serial primary key,
    fund_ticker VARCHAR(10) NOT NULL,
    date_reported DATE NOT NULL,
    symbol VARCHAR(30) NOT NULL,
    holding_percent FLOAT NOT NULL,
    CONSTRAINT unique_fund_symbol UNIQUE (fund_ticker, symbol, date_reported)
);

# %%
df = spy.top_holdings
df.columns
# Out:
# Index(['Name', 'Holding Percent'], dtype='object')

# %%
df.index
# Out:
# Index(['AAPL', 'MSFT', 'NVDA', 'AMZN', 'META', 'GOOGL', 'TSLA', 'AVGO', 'GOOG',
#        'BRK-B'],
#       dtype='object', name='Symbol')
